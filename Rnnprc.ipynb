# %%
import collections
import numpy as  np

# %%
def build_dataset(words):
    count=collections.Counter(words).most_common()
    dictionary=dict()
    for word, _ in count:
        print(word)
        dictionary[word]=len(dictionary)
    reverse_dictionary=dict(zip(dictionary.values(),dictionary.keys()))
    return dictionary,reverse_dictionary

# %%
training_file='f:/story2.txt'


def read_data(fname):
    with open(fname) as f:
        content=f.readlines()
    content=[x.strip() for x in content]
    content=[content[i].split() for i in range(len(content))]
    content=np.array(content)
    content=np.reshape(content,[-1,])
    return content

training_data=read_data(training_file)
print("Loaded training data...")
# Out:
# Loaded training data...

# %%
dictionary,reverse_dictionary=build_dataset(training_data)
# Out:
# i
# to
# you
# the
# of
# say
# just
# not
# is
# time
# god
# and
# was
# a
# In
# name
# law
# mohd
# ahmad
# khan
# sentence
# die
# if
# have
# any
# last
# word
# it
# do
# wait
# It
# when
# are
# going
# meet
# may
# show
# some
# mercy
# upon
# The
# night
# dark
# full
# terror
# Once
# upona
# in
# mumbai
# saw
# man
# walking
# on
# street
# he
# trying
# find
# something
# but
# sometimes
# can
# understand
# what
# people
# actually
# want
# findso
# left
# that
# path
# choose
# different
# one

# %%
def builDataset(words):
    for word in words:
        print(word)

# %%
#builDataset(training_data)

# %%
import cv2

# %%
import matplotlib.pyplot as plt
import numpy

# %%
img=cv2.imread('f:/ahmad.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(im_data, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.plot([200,300,400],[100,200,300],'c', linewidth=5)
plt.show()

# %%
img_data=cv2.resize(img,(50,50))

# %%
len(img_data)
# Out:
# 50

# %%
from tqdm import tqdm

# %%
import os
Train_dir='f:/images'

# %%
for img in tqdm(os.listdir(Train_dir)):
    path=os.path.join(Train_dir,img)
    im_data=cv2.imread(path,cv2.IMREAD_GRAYSCALE)
    im_data=cv2.resize(im_data,(50,50))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 106.39it/s]

# %%
len(im_data)
# Out:
# 50
